# %%
import pandas as pd
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]
df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})
print(df)
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %%
#1
df.iloc[1]
# Out:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %%
#2
#The loc() function is label based data selecting method which means that we have to pass the name of the row or column which we want to select. 
#The iloc() function is an indexed-based selecting method which means that we have to pass an integer index in the method to select a specific row/column.

# %%
#3
new_df = df.reindex([3,0,1,2])
print(new_df)
print(new_df.loc[2])
print(new_df.iloc[2])

#.loc is filtering on the basis of label value that is 2. and iloc is filtering on basis of index . hence difference in output.
# Out:
#         course_name  duration
# 3     Data Engineer         4
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# course_name    Big Data
# duration              6
# Name: 2, dtype: object
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %%
#4
import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
#Creating a dataframe:
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)
print(df1.mean())
print("--------------------")
print(df1['column_2'].std())
# Out:
# column_1    0.369393
# column_2    0.474574
# column_3    0.392155
# column_4    0.558052
# column_5    0.502954
# column_6    0.422802
# dtype: float64
# --------------------
# 0.3547211266594499

# %%
#5
df1['column_2'].iloc[1] = "xyz"
df1['column_2'].mean()

#string values are not supported by mean function
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 #5
#       2 df1['column_2'].iloc[1] = "xyz"
# ----> 3 df1['column_2'].mean()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
# ...

# %%
#6
#Window functions allow us to perform an operation with a given row’s data and data from another row that is a specified number of rows away — this “number of rows away value” is called the window.
#Aggregate Window Functions 
#Analytical Window Functions

# %%
#7
x =  pd.datetime.now()
print(x.month,x.year)
# Out:
# 3 2023
# /tmp/ipykernel_77/2516870443.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   x =  pd.datetime.now()

# %%
#8
from datetime import datetime
date1 = input("Enter date1: ")
date2 = input("Enter date2: ")
date1  = datetime.strptime(date1,"%Y-%m-%d")
date2  = datetime.strptime(date2,"%Y-%m-%d")
diff = date1 - date2
print(diff.days,diff.seconds)
diff_in_hours = diff.total_seconds() / 3600
print(diff_in_hours)
# Out:
# Enter date1:  2023-03-01
# Enter date2:  2023-02-27
# 2 0
# 48.0

# %%
#9
dataset = input("Enter path: ")
col = input("Enter column: ")
order = input("Select order True/False: ")
df = pd.read_csv(dataset)
df[col] = df[col].astype('category')
df.sort_values(by=[col], ascending = bool(order))
# Out:
# Enter path:  sales_data_sample.csv
# Enter column:  SALES
# Select order True/False:  True
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 2249        10425               11      43.83                6    482.13
# 1287        10407                6      90.19                3    541.14
# 2044        10408               15      36.93                1    553.95
# 1551        10280               20      28.88               12    577.60
# 1818        10419               15      42.67                7    640.05
# ...           ...              ...        ...              ...       ...
# 104         10403               66     100.00                9  11886.60
# 1062        10412               60     100.00                9  11887.80
# 53          10424               50     100.00                6  12001.00
# 744         10322               50     100.00                6  12536.50
# 598         10407               76     100.00                2  14082.80
#
# ...

# %%
#10
#sales_data_sample.csv
dataset = input("Enter path: ")
df = pd.read_csv(dataset)
ax = df.plot.bar(x='PRODUCTLINE', y='SALES', rot=0,stacked =True)
# Out:
# Enter path:  sales_data_sample.csv

# %%
#11
dataset = input("Enter path: ")
df = pd.read_csv(dataset)
df1 = pd.DataFrame({"Median":df['Score'].median(),"Mean":df['Score'].mean(),"Mode":df['Score'].mode()},index = [0,1,2])
df1.swapaxes(axis1="index", axis2="columns")
df1
# Out:
# Enter path:  scores.csv
#    Median  Mean  Mode
# 0    80.0  76.9  85.0
# 1    80.0  76.9   NaN
# 2    80.0  76.9   NaN
