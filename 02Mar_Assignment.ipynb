# %%
#1
#matplotlib is a data visualization library available in python. It is used to represent data in a graphical manner to find out trends and relations in data.
#Scatter plot
#Line plot
#bar plot
#3D PLOT
#HISTOgram plot

# %%
#2
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel("x Axis data")
plt.ylabel("y axis data")
# Out:
# Text(0, 0.5, 'y axis data')

# %%
#3
#With the subplot() function you can draw multiple plots in one figure.
import numpy as np
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2,2,1)
plt.plot(x,y)
x = np.array([0, 1, 2, 3, 4, 5])  
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2,2,2)
plt.plot(x,y)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2,2,3)
plt.plot(x,y)
x = np.array([0, 1, 2, 3, 4, 5])  
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,2,4)
plt.plot(x,y)

# %%
#4
#Bar plot is graphical representation between relation between categorical data and numerical data.
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.subplot(2,1,1)
plt.bar(company,profit)
plt.subplot(2,1,2)
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
#5
#Matplotlib's boxplot mainly provides a graphical summary of a data set with features such as minimum, first quartile, median, third quartile, and maximum.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data = [box1,box2]
#plt.subplot(2,1,1)
plt.boxplot(data)
#plt.subplot(2,1,2)
#plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9dbb06b9d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9dbb06bf10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9dbb06b730>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f9dbb094490>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9dbb094730>,
# ...
#  'means': []}
