# %%
#1
#Flask is a lightweight micro web development framework developed in python .It uses uWSGI as web server
#easy to use
#lightweight
#flexible

# %% [markdown]
# #2
# ![image.png](attachment:02aece50-9a4b-4be8-8511-12134c0b5ddc.png)

# %%
#3
#App Routing means mapping the URLs to a specific function that will handle the logic for that URL
# using @app.route('/') decorator above your method is used to map that method .

# %% [markdown]
# #4
# ![image.png](attachment:538ae271-80b4-40eb-a00b-490cca7b9744.png)
#
# ![image.png](attachment:6c28d111-a023-4df0-afba-30e37086bb22.png)

# %%
#5
#The url_for() function is used to build a URL to the specific function dynamically. The first argument is the name of the specified function, and then we can pass any number of keyword argument corresponding to the variable part of the URL.

from flask import *  
   
app = Flask(__name__)  
  
@app.route('/admin')  
def admin():  
    return 'admin'  

@app.route('/user/<name>')  
def user(name):  
    if name == 'admin':  
        return redirect(url_for('admin'))  

    if __name__ =='__main__':  
    app.run(debug = True)
